# %%
import matplotlib.pyplot as plt

# %%
# Data
stride = list(range(1, 21))
time_msec_set1 = [20.0, 30.0, 30.0, 40.0, 30.0, 40.0, 40.0, 50.0, 100.0, 60.0, 60.0, 60.0, 70.0, 110.0, 70.0, 70.0, 70.0, 80.0, 120.0, 80.0]
time_msec_set2 = [50.0, 40.0, 50.0, 50.0, 40.0, 60.0, 60.0, 40.0, 60.0, 70.0, 100.0, 60.0, 80.0, 80.0, 140.0, 80.0, 90.0, 140.0, 100.0, 100.0]


# Plot for Time (msec) comparison
plt.figure(figsize=(10, 6))
plt.plot(stride, time_msec_set1, linestyle='-', color='b', label='Time (msec) using gcc -O0')
plt.plot(stride, time_msec_set2, linestyle='-', color='r', label='Time (msec) using gcc -O2')
plt.xlabel('Stride')
plt.ylabel('Time (msec)')
plt.title('Comparison of Time (msec) Between gcc O0 and O2')
plt.legend()
plt.grid()
plt.show()

# %%
# Data
stride = list(range(1, 21))
rate_mbs = [1525.878906, 1907.348633, 1525.878906, 1525.878906, 1907.348633, 1271.565755, 1271.565755, 1907.348633, 1271.565755, 1089.913504, 762.939453, 1271.565755, 953.674316, 953.674316, 544.956752, 953.674316, 847.710503, 544.956752, 762.939453, 762.939453]
rate_mbs1 = [3814.697266, 2543.131510, 2543.131510, 1907.348633, 2543.131510, 1907.348633, 1907.348633, 1525.878906, 762.939453, 1271.565755, 1271.565755, 1271.565755, 1089.913504, 693.581321, 1089.913504, 1089.913504, 1089.913504, 953.674316, 635.782878, 953.674316] 

# Plot for Time (msec) comparison
plt.figure(figsize=(10, 6))
plt.plot(stride, rate_mbs , linestyle='-', color='b', label='rate (mbs) using gcc -O0')
plt.plot(stride, rate_mbs1, linestyle='-', color='r', label='rate (mbs) using gcc -O2')
plt.xlabel('Stride')
plt.ylabel('RATE (mbs)')
plt.title('Comparison of rate (mbs) Between gcc O0 and O2')
plt.legend()
plt.grid()
plt.show()
